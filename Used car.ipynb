# %%
import pandas as pd

# %%
data=pd.read_csv('used_car_dataset.csv')
data
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9582 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9582 non-null   object
#  1   model         9582 non-null   object
#  2   Year          9582 non-null   int64
#  3   Age           9582 non-null   int64
#  4   kmDriven      9535 non-null   object
#  5   Transmission  9582 non-null   object
#  6   Owner         9582 non-null   object
#  7   FuelType      9582 non-null   object
#  8   PostedDate    9582 non-null   object
#  9   AdditionInfo  9582 non-null   object
#  10  AskPrice      9582 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 823.6+ KB

# %%
data.describe()
# Out:
#               Year          Age
# count  9582.000000  9582.000000
# mean   2016.361094     7.638906
# std       4.087226     4.087226
# min    1986.000000     0.000000
# 25%    2014.000000     5.000000
# 50%    2017.000000     7.000000
# 75%    2019.000000    10.000000
# max    2024.000000    38.000000

# %%
data.describe(include='O')
# Out:
#                 Brand model   kmDriven Transmission  Owner FuelType  \
# count            9582  9582       9535         9582   9582     9582
# unique             39   400       1910            2      2        3
# top     Maruti Suzuki  City  65,000 km       Manual  first   Diesel
# freq             2720   330        198         4800   4800     3840
#
#        PostedDate                                 AdditionInfo    AskPrice
# count        9582                                         9582        9582
# unique         12                                         7307        1330
# top        Nov-24  BMW 5 Series 3.0 530D M Sport, 2016, Diesel  ₹ 4,50,000
# freq         8693                                           26         134

# %%
data.describe(include='all')
# Out:
#                 Brand model         Year          Age   kmDriven Transmission  \
# count            9582  9582  9582.000000  9582.000000       9535         9582
# unique             39   400          NaN          NaN       1910            2
# top     Maruti Suzuki  City          NaN          NaN  65,000 km       Manual
# freq             2720   330          NaN          NaN        198         4800
# mean              NaN   NaN  2016.361094     7.638906        NaN          NaN
# std               NaN   NaN     4.087226     4.087226        NaN          NaN
# min               NaN   NaN  1986.000000     0.000000        NaN          NaN
# 25%               NaN   NaN  2014.000000     5.000000        NaN          NaN
# 50%               NaN   NaN  2017.000000     7.000000        NaN          NaN
# 75%               NaN   NaN  2019.000000    10.000000        NaN          NaN
# max               NaN   NaN  2024.000000    38.000000        NaN          NaN
#
# ...

# %%
df=data.copy()

# %%
df
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# ...

# %%
df.pop('Transmission')
df
# Out:
#               Brand      model  Year  Age     kmDriven   Owner    FuelType  \
# 0             Honda       City  2001   23    98,000 km  second      Petrol
# 1            Toyota     Innova  2009   15  190000.0 km  second      Diesel
# 2        Volkswagen  VentoTest  2010   14    77,246 km   first      Diesel
# 3     Maruti Suzuki      Swift  2017    7    83,500 km  second      Diesel
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km   first      Petrol
# ...             ...        ...   ...  ...          ...     ...         ...
# 9577          Skoda    Octavia  2014   10   105,904 km  second      Diesel
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km   first  Hybrid/CNG
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km   first      Diesel
# 9580        Hyundai      Verna  2019    5    72,000 km   first      Petrol
# 9581        Hyundai    New i20  2021    3    83,228 km  second      Petrol
#
# ...

# %%
data.loc[0:14,'Brand':'Age']
# Out:
#             Brand                model  Year  Age
# 0           Honda                 City  2001   23
# 1          Toyota               Innova  2009   15
# 2      Volkswagen            VentoTest  2010   14
# 3   Maruti Suzuki                Swift  2017    7
# 4   Maruti Suzuki               Baleno  2019    5
# 5             BMW                   X3  2014   10
# 6          Toyota               Innova  2014   10
# 7             BMW             5 Series  2019    5
# 8   Maruti Suzuki  maruti-suzuki-dzire  2020    4
# 9            Ford             Ecosport  2017    7
# 10  Maruti Suzuki             Alto-K10  2018    6
# 11            Kia             Carnival  2021    3
# 12  Maruti Suzuki          Swift-Dzire  2012   12
# 13         Toyota              Corolla  2007   17
# 14  Mercedes-Benz            GLE COUPE  2021    3

# %%
df.iloc[0:14,0:4]
# Out:
#             Brand                model  Year  Age
# 0           Honda                 City  2001   23
# 1          Toyota               Innova  2009   15
# 2      Volkswagen            VentoTest  2010   14
# 3   Maruti Suzuki                Swift  2017    7
# 4   Maruti Suzuki               Baleno  2019    5
# 5             BMW                   X3  2014   10
# 6          Toyota               Innova  2014   10
# 7             BMW             5 Series  2019    5
# 8   Maruti Suzuki  maruti-suzuki-dzire  2020    4
# 9            Ford             Ecosport  2017    7
# 10  Maruti Suzuki             Alto-K10  2018    6
# 11            Kia             Carnival  2021    3
# 12  Maruti Suzuki          Swift-Dzire  2012   12
# 13         Toyota              Corolla  2007   17

# %%
df
# Out:
#               Brand      model  Year  Age     kmDriven   Owner    FuelType  \
# 0             Honda       City  2001   23    98,000 km  second      Petrol
# 1            Toyota     Innova  2009   15  190000.0 km  second      Diesel
# 2        Volkswagen  VentoTest  2010   14    77,246 km   first      Diesel
# 3     Maruti Suzuki      Swift  2017    7    83,500 km  second      Diesel
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km   first      Petrol
# ...             ...        ...   ...  ...          ...     ...         ...
# 9577          Skoda    Octavia  2014   10   105,904 km  second      Diesel
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km   first  Hybrid/CNG
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km   first      Diesel
# 9580        Hyundai      Verna  2019    5    72,000 km   first      Petrol
# 9581        Hyundai    New i20  2021    3    83,228 km  second      Petrol
#
# ...

# %%
ds=df.drop(columns=['Owner'],axis=1)
ds
# Out:
#               Brand      model  Year  Age     kmDriven    FuelType PostedDate  \
# 0             Honda       City  2001   23    98,000 km      Petrol     Nov-24
# 1            Toyota     Innova  2009   15  190000.0 km      Diesel     Jul-24
# 2        Volkswagen  VentoTest  2010   14    77,246 km      Diesel     Nov-24
# 3     Maruti Suzuki      Swift  2017    7    83,500 km      Diesel     Nov-24
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km      Petrol     Nov-24
# ...             ...        ...   ...  ...          ...         ...        ...
# 9577          Skoda    Octavia  2014   10   105,904 km      Diesel     Oct-24
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km  Hybrid/CNG     Nov-24
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km      Diesel     Nov-24
# 9580        Hyundai      Verna  2019    5    72,000 km      Petrol     Oct-24
# 9581        Hyundai    New i20  2021    3    83,228 km      Petrol     Nov-24
#
# ...

# %%
df
# Out:
#               Brand      model  Year  Age     kmDriven   Owner    FuelType  \
# 0             Honda       City  2001   23    98,000 km  second      Petrol
# 1            Toyota     Innova  2009   15  190000.0 km  second      Diesel
# 2        Volkswagen  VentoTest  2010   14    77,246 km   first      Diesel
# 3     Maruti Suzuki      Swift  2017    7    83,500 km  second      Diesel
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km   first      Petrol
# ...             ...        ...   ...  ...          ...     ...         ...
# 9577          Skoda    Octavia  2014   10   105,904 km  second      Diesel
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km   first  Hybrid/CNG
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km   first      Diesel
# 9580        Hyundai      Verna  2019    5    72,000 km   first      Petrol
# 9581        Hyundai    New i20  2021    3    83,228 km  second      Petrol
#
# ...

# %%
df.drop(columns=['Owner'],axis=1,inplace=True)

# %%
df
# Out:
#               Brand      model  Year  Age     kmDriven    FuelType PostedDate  \
# 0             Honda       City  2001   23    98,000 km      Petrol     Nov-24
# 1            Toyota     Innova  2009   15  190000.0 km      Diesel     Jul-24
# 2        Volkswagen  VentoTest  2010   14    77,246 km      Diesel     Nov-24
# 3     Maruti Suzuki      Swift  2017    7    83,500 km      Diesel     Nov-24
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km      Petrol     Nov-24
# ...             ...        ...   ...  ...          ...         ...        ...
# 9577          Skoda    Octavia  2014   10   105,904 km      Diesel     Oct-24
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km  Hybrid/CNG     Nov-24
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km      Diesel     Nov-24
# 9580        Hyundai      Verna  2019    5    72,000 km      Petrol     Oct-24
# 9581        Hyundai    New i20  2021    3    83,228 km      Petrol     Nov-24
#
# ...

# %%
df.nunique()
# Out:
# Brand             39
# model            400
# Year              32
# Age               32
# kmDriven        1910
# FuelType           3
# PostedDate        12
# AdditionInfo    7307
# AskPrice        1330
# dtype: int64

# %%
df['model'].unique()
# Out:
# array(['City', 'Innova', 'VentoTest', 'Swift', 'Baleno', 'X3', '5 Series',
#        'maruti-suzuki-dzire', 'Ecosport', 'Alto-K10', 'Carnival',
#        'Swift-Dzire', 'Corolla', 'GLE COUPE', 'Xcent', 'Seltos', 'Ertiga',
#        '3 Series GT', 'Endeavour', 'Innova Crysta', 'A3', 'KWID',
#        'Hector', 'Celerio', 'Vitara-Brezza', '2.8 Legender 4X2', 'S90',
#        'Venue', 'Creta', 'Alcazar', 'i20', 'E-Class', 'Polo', 'Verna',
#        'A4', 'Fortuner', 'C-Class', 'Kushaq', 'Ciaz', 'Safari', 'BRV',
#        'Duster', 'Wagon-R', 'Bolero Power Plus', 'Eon', 'Hector Plus',
#        'XUV500', 'GLS', 'i10', 'GLA Class', 'Carens', 'Ignis',
#        'Grand i10', 'Getz Prime', 'Ritz', 'Sonet', 'GLC Coupe',
#        'Scorpio-N', 'Cooper 3 DOOR', 'Nexon', 'Etios', 'CrossPolo',
#        'Vento', 'Range Rover Evoque', 'Indigo Ecs', 'Thar', 'Camry',
#        'Bolero', 'Brio', 'City ZX', 'WRV', 'Discovery Sport', 'Harrier',
#        'Zest', 'Eeco', 'Swift Dzire', 'Sx4', 'Kodiaq', 'Altroz',
# ...

# %%
df['kmDriven'].unique()
# Out:
# array(['98,000 km', '190000.0 km', '77,246 km', ..., '243,000 km',
#        '43,700 km', '83,228 km'], dtype=object)

# %%
df['kmDriven'].dtype
# Out:
# dtype('O')

# %%
df.select_dtypes('int64')
# Out:
#       Year  Age
# 0     2001   23
# 1     2009   15
# 2     2010   14
# 3     2017    7
# 4     2019    5
# ...    ...  ...
# 9577  2014   10
# 9578  2020    4
# 9579  2013   11
# 9580  2019    5
# 9581  2021    3
#
# [9582 rows x 2 columns]

# %%
df['Year+1']=df['Year']+1
df.select_dtypes('int64')
# Out:
#       Year  Age  Year+1
# 0     2001   23    2002
# 1     2009   15    2010
# 2     2010   14    2011
# 3     2017    7    2018
# 4     2019    5    2020
# ...    ...  ...     ...
# 9577  2014   10    2015
# 9578  2020    4    2021
# 9579  2013   11    2014
# 9580  2019    5    2020
# 9581  2021    3    2022
#
# [9582 rows x 3 columns]

# %%
df.loc[9500]
# Out:
# Brand                                   Hyundai
# model                                       i10
# Year                                       2010
# Age                                          14
# kmDriven                             130,000 km
# FuelType                             Hybrid/CNG
# PostedDate                               Nov-24
# AdditionInfo    Hyundai i10 2010 CNG & Hybrids.
# AskPrice                             ₹ 1,60,000
# Year+1                                     2011
# Name: 9500, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9582 entries, 0 to 9581
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9582 non-null   object
#  1   model         9582 non-null   object
#  2   Year          9582 non-null   int64
#  3   Age           9582 non-null   int64
#  4   kmDriven      9535 non-null   object
#  5   FuelType      9582 non-null   object
#  6   PostedDate    9582 non-null   object
#  7   AdditionInfo  9582 non-null   object
#  8   AskPrice      9582 non-null   object
#  9   Year+1        9582 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 748.7+ KB

# %%
new_data={'Brand':'BMW','model':'carne','Year':2010,'Age':14,'kmDriven':'130,000 km','FuelType':'Petrol','PostedDate':'27-12-17','AdditionInfo':'none','AskPrice':'6,00,000','Year+1':2011}
new_data=pd.DataFrame([new_data])
new_data
# Out:
#   Brand  model  Year  Age    kmDriven FuelType PostedDate AdditionInfo  \
# 0   BMW  carne  2010   14  130,000 km   Petrol   27-12-17         none
#
#    AskPrice  Year+1
# 0  6,00,000    2011

# %%
df=pd.concat([df.iloc[:9579],new_data,df.iloc[9579:]]).reset_index(drop=True)
df
# Out:
#               Brand      model  Year  Age     kmDriven FuelType PostedDate  \
# 0             Honda       City  2001   23    98,000 km   Petrol     Nov-24
# 1            Toyota     Innova  2009   15  190000.0 km   Diesel     Jul-24
# 2        Volkswagen  VentoTest  2010   14    77,246 km   Diesel     Nov-24
# 3     Maruti Suzuki      Swift  2017    7    83,500 km   Diesel     Nov-24
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km   Petrol     Nov-24
# ...             ...        ...   ...  ...          ...      ...        ...
# 9579            BMW      carne  2010   14   130,000 km   Petrol   27-12-17
# 9580            BMW      carne  2010   14   130,000 km   Petrol   27-12-17
# 9581  Maruti Suzuki       Ritz  2013   11    92,000 km   Diesel     Nov-24
# 9582        Hyundai      Verna  2019    5    72,000 km   Petrol     Oct-24
# 9583        Hyundai    New i20  2021    3    83,228 km   Petrol     Nov-24
#
# ...

# %%
df.duplicated().sum()
# Out:
# 730

# %%
df[df.duplicated()]
# Out:
#               Brand      model  Year  Age     kmDriven    FuelType PostedDate  \
# 146            Audi         A3  2015    9    42,000 km      Diesel     Nov-24
# 152           Honda       City  2016    8    93,000 km      Petrol     Nov-24
# 199            Audi         A3  2015    9    42,000 km      Diesel     Nov-24
# 221          Toyota      Camry  2015    9    68,000 km      Petrol     Nov-24
# 230   Mercedes-Benz  GLE COUPE  2021    3    32,000 km      Petrol     Oct-24
# ...             ...        ...   ...  ...          ...         ...        ...
# 9518     Volkswagen  VentoTest  2014   10    72,900 km      Diesel     Nov-24
# 9540  Maruti Suzuki  Celerio-X  2020    4   142,000 km  Hybrid/CNG     Nov-24
# 9542  Maruti Suzuki    Celerio  2015    9  103000.0 km      Petrol     Nov-24
# 9562            BMW   5 Series  2016    8    47,000 km      Diesel     Nov-24
# 9580            BMW      carne  2010   14   130,000 km      Petrol   27-12-17
#
# ...

# %%
df.loc[9580]
# Out:
# Brand                  BMW
# model                carne
# Year                  2010
# Age                     14
# kmDriven        130,000 km
# FuelType            Petrol
# PostedDate        27-12-17
# AdditionInfo          none
# AskPrice          6,00,000
# Year+1                2011
# Name: 9580, dtype: object

# %%
df.iloc[9580,7]='BMW Manuel'

# %%
df.loc[9580]
# Out:
# Brand                  BMW
# model                carne
# Year                  2010
# Age                     14
# kmDriven        130,000 km
# FuelType            Petrol
# PostedDate        27-12-17
# AdditionInfo    BMW Manuel
# AskPrice          6,00,000
# Year+1                2011
# Name: 9580, dtype: object

# %%
dc=df.drop_duplicates()

# %%
dc
# Out:
#               Brand      model  Year  Age     kmDriven FuelType PostedDate  \
# 0             Honda       City  2001   23    98,000 km   Petrol     Nov-24
# 1            Toyota     Innova  2009   15  190000.0 km   Diesel     Jul-24
# 2        Volkswagen  VentoTest  2010   14    77,246 km   Diesel     Nov-24
# 3     Maruti Suzuki      Swift  2017    7    83,500 km   Diesel     Nov-24
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km   Petrol     Nov-24
# ...             ...        ...   ...  ...          ...      ...        ...
# 9579            BMW      carne  2010   14   130,000 km   Petrol   27-12-17
# 9580            BMW      carne  2010   14   130,000 km   Petrol   27-12-17
# 9581  Maruti Suzuki       Ritz  2013   11    92,000 km   Diesel     Nov-24
# 9582        Hyundai      Verna  2019    5    72,000 km   Petrol     Oct-24
# 9583        Hyundai    New i20  2021    3    83,228 km   Petrol     Nov-24
#
# ...

# %%
dc.drop[9579],reset_index=True
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 dc.drop[9579],reset_index=True
#
# TypeError: cannot unpack non-iterable bool object
